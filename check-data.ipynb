# %%
import json
import random
import cv2
import matplotlib.pyplot as plt
import os

# %%
scenes = json.load(open('/home/xingrui/publish/3D-Aware-VQA/superclevr-3D-question/output/ver_mask_30k_clean/superCLEVR_scenes_30k_occlusion.json', 'r'))

# %% [markdown]
# # Read image

# %%
ImageDIR = '/home/xingrui/publish/3D-Aware-VQA/superclevr-3D-question/output/ver_mask_30k_clean/images'
# SceneDIR = '/home/xingrui/publish/3D-Aware-VQA/superclevr-3D-question/output/ver_mask_30k/scenes_with_occlusion'

# %%
# print(scenes['scenes'][rand_id]['occlusion'])
rand_id = 29990
scene = scenes['scenes'][rand_id]['objects']
occlusion = scenes['scenes'][rand_id]['occlusion']
parts = [i['parts'] for i in scene]
print(rand_id)
for i, obj in enumerate(scene):
    print("{} {} {} {},{}".format(i, obj['color'],  obj['material'], obj['shape'], occlusion[str(i)]['obj'][0]))

image_filename = scenes['scenes'][rand_id]['image_filename']
print(image_filename)

image_name = ImageDIR + '/' + image_filename
image = cv2.imread(image_name)[:,:,::-1]
plt.imshow(image)
# Out:
# 29990
# 0 gray rubber school,0
# 1 green rubber jet,0
# 2 gray rubber truck,0
# 3 yellow metal suv,0
# 4 green rubber road,0
# 5 green rubber wagon,0
# superCLEVR_new_029992.png

# %%
img_ids = [i['image_index'] for i in scenes['scenes']]

# %%
set(range(0, 30000)) - set(img_ids)
# Out:
# {20999, 24653}

# %% [markdown]
# # Questions

# %%
# questions = {
#     'object_occlusion': json.load(open('/home/xingrui/publish/3D-Aware-VQA/superclevr-3D-question/output/ver_mask_30k_clean/questions/superclevr_questions_obj_occlusion.json')),
#     'occlusion': json.load(open('/home/xingrui/publish/3D-Aware-VQA/superclevr-3D-question/output/ver_mask_30k_clean/questions/superclevr_questions_occlusion.json')),
#     'parts': json.load(open('/home/xingrui/publish/3D-Aware-VQA/superclevr-3D-question/output/ver_mask_30k_clean/questions/superclevr_questions_parts.json')),
#     'pose': json.load(open('/home/xingrui/publish/3D-Aware-VQA/superclevr-3D-question/output/ver_mask_30k_clean/questions/superclevr_questions_pose.json'))
# }

# %%
# with open('/home/xingrui/publish/3D-Aware-VQA/superclevr-3D-question/output/ver_mask_30k_clean/questions/superclevr_questions_pose.json', 'w') as f:
#     json.dump(questions['pose'], f)
