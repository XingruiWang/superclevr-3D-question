# %%
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visual_res = [[[59.96, 53.95, 50.66],
        [57.41, 53.28, 50.18],
        [55.95, 53.11, 50.47]],
        [[95.13, 92.31, 90.81],
        [84.5, 89.1, 86.33],
        [76.85, 78.66, 85.08]],
        [[93.36, 84.3, 82.97],
        [83.34, 82.36, 81.27],
        [79.71, 79.94, 80.71]]]
visual_res = np.array(visual_res)

# %%
plt.clf()
v_min = 50
v_max = 100
f,axs = plt.subplots(1,4, 
            gridspec_kw={'width_ratios':[1,1,1,0.08]})
for i in range(3):
    sns.heatmap(visual_res[i], xticklabels=['easy', 'mid', 'hard'], yticklabels=['easy', 'mid', 'hard'], 
                     linewidth=0.5, vmin=None, vmax=None, ax=axs[i])#,
                     #cbar=(i==2), cbar_ax=axs[-1]) #cmap="YlGnBu"

plt.tight_layout()
plt.show()
# plt.savefig(save_pth)

# %%
redund_res = [[[51.42, 52.54, 53.51],
    [50.39, 53.28, 54.78],
    [46.14, 52.3, 71.47]],
    [[88.64, 88.82, 90.33],
    [88.45, 89.1, 91.45],
    [87.94, 88.34, 91.16]],
    [[83.94, 80.37, 66.28],
    [82.7, 82.36, 70.36],
    [78.48, 84.05, 90.42]]]
redund_res = np.array(redund_res)

# %%
plt.clf()
v_min = 50
v_max = 100
f,axs = plt.subplots(1,4, 
            gridspec_kw={'width_ratios':[1,1,1,0.08]})
for i in range(3):
    sns.heatmap(redund_res[i], xticklabels=['easy', 'mid', 'hard'], yticklabels=['easy', 'mid', 'hard'], 
                     linewidth=0.5, vmin=None, vmax=None, ax=axs[i])#,
#                     cmap="YlGnBu", cbar=(i==2), cbar_ax=axs[-1]) #YlGnBu

plt.tight_layout()
plt.show()

# %%
comp_res = [[[53.28, 57, 56.1],
        [52.41, 60.57, 56.67],
        [52.96, 57.37, 60.53]],
        [[89.1, 82.52, 83.77],
        [78.89, 87.18, 84.2],
        [78.4, 81.55, 88.84]],
        [[83.36, 77.03, 82.43],
        [79.46, 82.45, 83.93],
        [80.03, 77.41, 87.24]]]
comp_res = np.array(comp_res)

# %%
plt.clf()
v_min = 50
v_max = 100
f,axs = plt.subplots(1,4, 
            gridspec_kw={'width_ratios':[1,1,1,0.08]})
for i in range(3):
    sns.heatmap(comp_res[i], xticklabels=['easy', 'mid', 'hard'], yticklabels=['easy', 'mid', 'hard'], 
                     linewidth=0.5, vmin=None, vmax=None, ax=axs[i])#,
#                     cmap="YlGnBu", cbar=(i==2), cbar_ax=axs[-1]) #YlGnBu
plt.tight_layout()
plt.show()
